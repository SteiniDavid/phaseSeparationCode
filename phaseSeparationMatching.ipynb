# %%
import numpy as np
import os

# %%
values = np.loadtxt('phase-separation-data.txt', skiprows=1)

# %%
#create the file name for matching
# final_tstep_pa0_pb10_xa10.png

for i in range(0, len(values)):
    fileName = 'final_tstep_pa'+str(int(values[i][0]))+'_pb'+str(int(values[i][1]))+'_xa'+str(int(values[i][2]))
    print fileName
    #Goes to directory with data
    os.chdir("..")
    print os.getcwd()
    os.chdir("Data/LFPICS")
    print os.getcwd()
    
    os.rename(fileName+'.png', fileName+'_ph'+str(int(values[i][3]))+'.png')
    os.chdir("..")
    os.chdir("..")
    print os.getcwd()
    os.chdir("phaseSeparationCode")
    print os.getcwd()
    
    #files = os.listdir('gsds')
    
    #print(fileName)
# Out:
# final_tstep_pa0_pb100_xa10
# /Users/Steini/Klosta Group/phaseSeparation
# /Users/Steini/Klosta Group/phaseSeparation/Data/LFPICS
# /Users/Steini/Klosta Group/phaseSeparation
# /Users/Steini/Klosta Group/phaseSeparation/phaseSeparationCode
# final_tstep_pa0_pb100_xa20
# /Users/Steini/Klosta Group/phaseSeparation
# /Users/Steini/Klosta Group/phaseSeparation/Data/LFPICS
# /Users/Steini/Klosta Group/phaseSeparation
# /Users/Steini/Klosta Group/phaseSeparation/phaseSeparationCode
# final_tstep_pa0_pb100_xa30
# /Users/Steini/Klosta Group/phaseSeparation
# /Users/Steini/Klosta Group/phaseSeparation/Data/LFPICS
# /Users/Steini/Klosta Group/phaseSeparation
# /Users/Steini/Klosta Group/phaseSeparation/phaseSeparationCode
# final_tstep_pa0_pb100_xa40
# /Users/Steini/Klosta Group/phaseSeparation
# /Users/Steini/Klosta Group/phaseSeparation/Data/LFPICS
# /Users/Steini/Klosta Group/phaseSeparation
# /Users/Steini/Klosta Group/phaseSeparation/phaseSeparationCode
# final_tstep_pa0_pb100_xa50
# ...
